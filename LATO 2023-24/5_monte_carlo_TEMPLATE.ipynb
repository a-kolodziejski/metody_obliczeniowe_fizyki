# %% [markdown]
# Przed przystąpieniem do rozwiązywania zadań, przeczytaj artykuł na Wikipedii ;-) https://pl.wikipedia.org/wiki/Metoda_Monte_Carlo

# %% [markdown]
# **Zad. 1** Pierwszym zadaniem będzie znalezienie przybliżonej wartości stałej $\pi$ i sprawdzenie, czy wartość podawana w szkołach jest prawdziwa (pruskiemu modelowi szkolnictwa należy zawsze patrzeć na ręce ;-)

# %%
import random

# %%
def pi(liczba_probek):
  # Zdefiniuj zmienną, która będzie przechowywała liczbę punktów leżących wewnątrz okręgu jednostkowego
  ### TWÓJ KOD TUTAJ ###
  for _ in range(liczba_probek):
    # Wylosuj współrzędną x oraz y punktu leżącego w obrębie kwadratu jednostkowego. Wsk.: użyj funkcji random.random
    x = ### TWÓJ KOD TUTAJ ###
    y = ### TWÓJ KOD TUTAJ ###
    # Sprawdź, czy wylosowany punkt leży w ćwiartce koła jednostkowego.
    # Jeśli tak, zwiększ wartość zmiennej przechowującej liczbę punktów leżących wewnątrz okręgu
    if ### TWÓJ KOD TUTAJ ###:
      wewnatrz_okregu += ### TWÓJ KOD TUTAJ ###
  # Oblicz przybliżoną wartośc stałej pi (nie zapomnij pomnozyć wyniku przez 4)
  pi_przyblizone = ### TWÓJ KOD TUTAJ ###
  return pi_przyblizone

# Testujemy funkcję
liczba_probek = 100000
pi_przyblizone = pi(liczba_probek)
print(f"Przybliżenie liczby π po {liczba_probek} próbach: {pi_przyblizone}")

# %% [markdown]
# **Zad. 2.** Oblicz przybliżoną wartość $\int_0^1{e^{-x^2}}dx$.

# %%
import numpy as np

# %%
# Zdefiniuj funkcję do scałkowania. Wskazówka: funkcja np.exp
def funkcja_do_scalkowania(x):
    return ### TWÓJ KOD TUTAJ ###

def calkowanie_monte_carlo(func, a, b, liczba_probek):
  # Wylosuj liczba_probek punktów na osi OX w przedziale (a, b). Wskazówka: funkcja np.random.uniform
  losowe_punkty_na_osi_x_w_przedziale_a_b = ### TWÓJ KOD TUTAJ ###
  # Oblicz wartość całkowanej funkcji dla powyzszych punktów na osi OX
  wartosc_funkcji_w_wyzej_wylosowanych_punktach = ### TWÓJ KOD TUTAJ ###
  # Oblicz wartość średnią funkcji na odcinku (a, b). Wskazówka: funkcji np.mean
  wartosc_srednia = ### TWÓJ KOD TUTAJ ###
  # Oblicz przybliżoną wartość całki jako długość przedziału * średnia wartość funkcji na przedziale
  przyblizona_wartosc_calki = ### TWÓJ KOD TUTAJ ###
  return przyblizona_wartosc_calki

# Parametry
a = 0  # dolna granica całkowania
b = 1  # górna granica całkowania
liczba_probek = 100000

# Wywołanie funkcji
przyblizona_wartosc_calki = calkowanie_monte_carlo(funkcja_do_scalkowania, a, b, liczba_probek)
print(f"Przybliżona wartość całki funkcji na przedziale [{a}, {b}]: {przyblizona_wartosc_calki}")

# %% [markdown]
# **Zad.2.b** Porównaj otrzymany wynik z wynikiem uzyskanym za pomocą funkcji `scipy.integrate.quad`

# %%
import scipy.integrate as integrate

# %%
### TWÓJ KOD TUTAJ ###
