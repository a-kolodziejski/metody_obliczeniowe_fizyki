# %% [markdown]
# ### Implementacja metody Newtona

# %%
import numpy as np

# %%
def newton_method(f, f_prim, x0, eps=1e-6, max_iter=1000):
  """
    Implementacja metody Newtona rozwiązywania równań.

    Args:
      f (callable): funkcja, której miejsca zerowego szukamy
      f_prim (callable): pochodna funkcji, której miejsca zerowego szukamy
      x0 (float): punkt początkowy metody Newtona
      eps (float): zadana dokładność
      max_iter (int): maksymalna liczba kroków iteracji algorytmu
    Returns:
      x taki, że |f(x)| < eps lub podnosi wyjątek, jeśli rozwiązania nie uda się znaleźć

  """
  # Przypisanie punktu początkowego do zmiennej x
  x = x0
  # Główna pętla algorytmu Newtona
  for i in range(### TWÓJ KOD TUTAJ ###):
    # Obliczenie wartości funkcji w punkcie x
    fx = ### TWÓJ KOD TUTAJ ###
    # Jeśli wartość funkcji w punkcie x mniejsza od zadanej dokładności, to zwróć x
    if ### TWÓJ KOD TUTAJ ###:
      return x
    # Obliczenie wartość pochodnej w x
    fpx = ### TWÓJ KOD TUTAJ ###
    # Sprawdzenie, czy pochodna jest równa 0
    if fpx == 0:
      raise ValueError(f"Pochodna równa 0. Spróbuj użyć innej wartości początkowej niż x0 = {x0}")
    # Nowy x równa się stary x - poprawka wynikająca ze wzoru Newtona
    x = ### TWÓJ KOD TUTAJ ###
  # Jeśli wykonano więcej niż max_iter kroków, to rozwiązania nie udało się znaleźć
  raise ValueError("Osiągnięto maksymalną liczbę kroków iteracji. Rozwiązania nie udało się znaleźć. Spróbuj użyć większej liczby kroków lub wybierz inny punkt początkowy.")

# %% [markdown]
# **Zad. 1**. Zastosować program do policzenia zera funkcji $f(x) = e^x-1.5-\arctan{x}$. Użyj $x_0=-7$.
