# %% [markdown]
# ### Implementacja algorytmu bisekcji

# %%
def bisection(func, a, b, eps=1e-6, max_iter=1000):
  """
  Implementacja algorytmu bisekcji.
  Args:
    func (callable): funkcja, której miejsce zerowe chcemy znaleźć
    a (float): lewy koniec przedziału poszukiwań rozwiązania
    b (float): prawy koniec przedziału poszukiwań rozwiązania
    eps (float): dokładność obliczeń
    max_iter (int): maksymalna liczba iteracji algorytmu
  Returns:
    midpoint (float lub None): rozwiązanie, jeśli uda się je znaleźć, w przeciwnym przypadku wartość None
  """
  # Sprawdź, czy znaki funkcji na końcach przedziału są różne
  if ### TWÓJ KOD TUTAJ ###
    raise ValueError("Wartości funkcji na końcach przedziału nie mają różnych znaków!")
  # Definicja zmiennej przechowującej numer kroku iteracji
  iter_count = 0
  # Pętlę przerwywamy jeśli przekroczymy maksymalną liczbę kroków iteracji i nie znajdziemy dostatecznie dobrego rozwiązania
  while ### TWÓJ KOD TUTAJ ###:
    midpoint = ### TWÓJ KOD TUTAJ ###
    # Jeśli nasze oszacowanie miejsca zerowego jest dodstatecznie dobre -> zwróć wynik
    if ### TWÓJ KOD TUTAJ ###:
      return ### TWÓJ KOD TUTAJ ###
    # W przeciwnym razie dostosuj odpowiednio końce przedziału
    elif func(midpoint) * func(a) < 0:
      ### TWÓJ KOD TUTAJ ###
    else:
      ### TWÓJ KOD TUTAJ ###
    # Zwiększamy wartość zmiennej iter_count
    iter_count += 1

  # Jeśli nie znajdziemy dostatecznie dobrego rozwiązania, to zwracamy pustą wartość
  return None

# %% [markdown]
# ### **Zad. 1**. Za pomocą napisanego programu znaleźć pierwiastek równania $e^{-x}=\sin{x}$ najbliższy 0.

# %% [markdown]
# ### **Zad. 2.** Znaleźć pierwiastek równania
# $x^8 - 36x^7 + 546x^6 - 4536x^5 +22449 x^4 - 67284 x^3 + 118124 x^2 - 109584 x + 40320 =0$,
# w przedziale $[5.5 , 6.5]$. Powtórzyć obliczenia po zmianie współczynnika 36 na 36.001.

# %%
### TWÓJ KOD TUTAJ ###
