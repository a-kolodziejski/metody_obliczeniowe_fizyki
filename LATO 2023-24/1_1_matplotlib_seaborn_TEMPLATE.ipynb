# %% [markdown]
# # Wizualizacja danych z użyciem Matplotlib i Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Zadanie 1: Tworzenie prostego wykresu liniowego
# Stwórz wykres liniowy dla danych `x` i `y`. Dodaj etykiety osi oraz tytuł wykresu. (wskazówka: użyj funkcji `plt.plot()` oraz `plt.xlabel()`, `plt.ylabel()`, `plt.title()`)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 2: Tworzenie wykresu słupkowego
# Stwórz wykres słupkowy dla danych `kategorie` i `wartosci`. Dodaj etykiety osi oraz tytuł wykresu. (wskazówka: użyj funkcji `plt.bar()`)

# %%
kategorie = ['A', 'B', 'C', 'D']
wartosci = [15, 25, 30, 20]
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 3: Tworzenie histogramu
# Stwórz histogram dla 1000 losowych liczb z rozkładu normalnego. (wskazówka: użyj funkcji `np.random.normal()` oraz `plt.hist()`)

# %%
data = ### Twój kod tutaj ###
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 4: Tworzenie wykresu punktowego
# Stwórz wykres punktowy dla danych `x` oraz `y`. Dodaj etykiety osi oraz tytuł wykresu. (wskazówka: użyj funkcji `plt.scatter()`)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 5: Tworzenie wykresu pudełkowego
# Stwórz wykres pudełkowy dla danych `data`. (wskazówka: użyj funkcji `plt.boxplot()`). Jak interpretujesz otrzymany wykres?

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 6: Tworzenie wykresu z użyciem Seaborn
# Stwórz wykres liniowy dla danych `x` oraz `y`  używając biblioteki Seaborn. (wskazówka: użyj funkcji `sns.lineplot()`)

# %%
x = np.arange(10)
y = np.random.rand(10)
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 7: Tworzenie heatmapy z użyciem Seaborn
# Stwórz heatmapę dla macierzy korelacji `data`. (wskazówka: użyj funkcji `sns.heatmap()`). Jak interpretujesz otrzymany wykres?

# %%
data = np.random.rand(10, 10)
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 8: Tworzenie wykresu słupkowego z użyciem Seaborn
# Stwórz wykres słupkowy dla danych `kategorie` oraz `wartosci` używając biblioteki Seaborn. (wskazówka: użyj funkcji `sns.barplot()`)

# %%
kategorie = ['A', 'B', 'C', 'D']
wartosci = [15, 25, 30, 20]
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 9: Tworzenie wykresu punktowego z użyciem Seaborn
# Stwórz wykres punktowy dla danych `x` oraz `y` używając biblioteki Seaborn. (wskazówka: użyj funkcji `sns.scatterplot()`)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
### Twój kod tutaj ###
plt.show()

# %% [markdown]
# ## Zadanie 10: Tworzenie wykresu pudełkowego z użyciem Seaborn
# Stwórz wykres pudełkowy dla tablicy `data` używając biblioteki Seaborn. (wskazówka: użyj funkcji `sns.boxplot()`). Zinterpretuj otrzymany wykres.

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
### Twój kod tutaj ###
plt.show()
