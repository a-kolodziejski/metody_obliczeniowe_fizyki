# %% [markdown]
# ## Importy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Zad.** Napisz program do interpolacji używając wzoru interpolacyjnego Lagrange'a i znajdź wielomian interpolujący dla punktów $(x,y)=\{(5.0, 1.0),(-7.0,-23.0),(-6.0,-54.0),(0.0,-954.0)\}$. Naszkicuj wielomiany bazy  ℓi  oraz osobno wykres wielomianu interpolującego i wszystkie punkty interpolowane.

# %%
# Wprowadź dane (funkcja np.array)
data = ### TWÓJ KOD TUTAJ ###

# Zdefiniuj zmienną N (liczba wielomianów bazy). Wskazówka: atrybut shape
N = ### TWÓJ KOD TUTAJ ###

# Stwórz siatkę stu punktów od -8 do 6
x = ### TWÓJ KOD TUTAJ ###

# Stwórz tablicę jedynek, gdzie każdy wiersz będzie zawierał wartości wielomianów bazowych dla wyżej zdefiniowanej siatki punktów
lagrange_poly = ### TWÓJ KOD TUTAJ ###

# Oblicz wartości wielomianów bazy dla siatki punktów
for i in range(N):
    for j in range(N):
        if ### TWÓJ KOD TUTAJ ###:
            lagrange_poly[### TWÓJ KOD TUTAJ ###] *= ### TWÓJ KOD TUTAJ ###


# Znajdź wzór Lagrange'a
# Zdefiniuj tablicę zer, która będzie zawierać wartości wielomianu interpolującego Lagrange'a dla siatki punktów x
p = ### TWÓJ KOD TUTAJ ###
for n in range(N):
    p += ### TWÓJ KOD TUTAJ ###

# %% [markdown]
# ### Jeśli wszystko jest OK, to poniższy kod wyprodukuje superaśne wykresy

# %%
fig2 = plt.figure()
axes = fig2.add_subplot(1, 1, 1)

for i in range(N):
    axes.plot(x, lagrange_poly[i, :], label="$\ell_{%s}(x)$" % i)



axes.set_title("Wielomiany $\ell_i(x)$")
axes.set_xlabel("x")
axes.set_ylabel("$\ell_i(x)$")
axes.legend(loc=2)


fig = plt.figure()
axes = fig.add_subplot(1, 1, 1)
axes.plot(x, p, label="$P_{%s}(x)$" % N)
for point in data:
    axes.plot(point[0], point[1], 'ko')
axes.set_title("$P_N(x)$")
axes.set_xlabel("x")
axes.set_ylabel("$P_N(x)$")


plt.show()
