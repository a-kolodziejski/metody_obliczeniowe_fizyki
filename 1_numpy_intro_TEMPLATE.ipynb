# %% [markdown]
# ## Tworzenie i manipulowanie tablicami NumPy

# %%
import numpy as np

# %% [markdown]
# Zad. 1. Stwórz tablicę jednowymiarową o długości 5, która zawiera liczby od 0 do 4. (wskazówka: funkcja `arange`)

# %%
arr = ### Twój kod tutaj ###
print(arr)

# %% [markdown]
# Zad. 2. Stwórz tablicę dwuwymiarową o wymiarach 3x3, która zawiera same zera. (wskazówka: funkcja `zeros`)

# %%
arr = ### Twój kod tutaj ###
print(arr)

# %% [markdown]
# Zad. 3. Stwórz tablicę dwuwymiarową o wymiarach 4x4, która zawiera same jedynki. (wskazówka: funkcja `ones`)

# %%
arr = ### Twój kod tutaj ###
print(arr)

# %% [markdown]
# Zad. 4. Stwórz tablicę jednowymiarową zawierającą 10 równoodległych liczb między 0 a 5. (wskazówka: funkcja `linspace`)

# %%
arr = ### Twój kod tutaj ###
print(arr)

# %% [markdown]
# ## Operacje na tablicach NumPy

# %% [markdown]
# Zad. 5a. Stwórz dwie tablice o wymiarach 2x2 zawierające losowe liczby całkowite od 1 do 10. Następnie wykonaj dodawanie tych tablic. (wskazówka: funkcja `np.random.randint`)

# %%
arr1 = ### Twój kod tutaj ###
arr2 = ### Twój kod tutaj ###
result = arr1 + arr2
print(result)

# %% [markdown]
# Zad. 5b. Dodaj 5 do każdego elementu tablicy jednowymiarowej.

# %%
arr = np.array([1, 2, 3, 4, 5])
arr_plus_5 = ### Twój kod tutaj ###
print(arr_plus_5)

# %% [markdown]
# Zad. 6. Stwórz dwie tablice o wymiarach 3x3 zawierające losowe liczby rzeczywiste. Następnie wykonaj mnożenie element-wise tych tablic. (wskazówka: funkcja `np.random.normal`)

# %%
arr1 = ### Twój kod tutaj ###
arr2 = ### Twój kod tutaj ###
result = arr1 * arr2
print(result)

# %% [markdown]
# Zad. 7. Stwórz jednowymiarową tablicę zawierającą liczby od 1 do 10. Następnie podnieś każdy element tej tablicy do kwadratu.

# %%
arr = ### Twój kod tutaj ###
result = ### Twój kod tutaj ###
print(result)

# %% [markdown]
# ## Indeksowanie i wycinanie tablic NumPy

# %% [markdown]
# Zad. 8. Stwórz jednowymiarową tablicę zawierającą liczby od 0 do 9. Wybierz i wyświetl elementy od indeksu 3 do 7 (włącznie).

# %%
arr = ### Twój kod tutaj ###
subset = ### Twój kod tutaj ###
print(subset)

# %% [markdown]
# Zad. 9. Stwórz dwuwymiarową tablicę o wymiarach 4x4 zawierającą liczby od 1 do 16 (zrobione za Ciebie. Zapoznaj się z funkcją `reshape`). Wybierz i wyświetl drugą kolumnę tej tablicy.

# %%
arr = np.arange(1, 17).reshape(4, 4)
column = ### Twój kod tutaj ###
print(column)

# %% [markdown]
# Zad. 10. (**WAŻNE**) Stwórz dwuwymiarową tablicę o wymiarach 3x3 zawierającą losowe liczby całkowite od 1 do 10. Wybierz i wyświetl tylko te elementy, które są większe niż 5.

# %%
arr = ### Twój kod tutaj ###
subset = ### Twój kod tutaj ###
print(subset)
