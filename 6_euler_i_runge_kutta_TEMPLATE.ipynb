# %% [markdown]
# **Zad. 1.** Zapoznać się z rozdziałami 2.1 oraz 3 https://home.agh.edu.pl/~kszopa/wp-content/uploads/2021/12/MN_lab5.pdf

# %% [markdown]
# **Zad. 2.** Zaimplementować metodę Eulera oraz Rungego-Kutty

# %%
# Importy
import numpy as np
import matplotlib.pyplot as plt

# %%
# Metoda Eulera
def euler(x, y, h, equation):
  '''
  Implementacja metody Eulera.

  Args:
    x (float): współrzędna x
    y (float): współrzędna y
    h (float): krok metody Eulera
    equation (callable): prawa strona równania różniczkowego postaci dy/dx = f(x, y)
  '''
  y_next = ### TWÓJ KOD TUTAJ ###
  return y_next

# %%
# Metoda Runge-Kutty
def runge_kutta(x, y, h, equation):
  '''
  Implementacja metody RK-4.

  Args:
    x (float): współrzędna x
    y (float): współrzędna y
    h (float): krok metody RK-4
    equation (callable): prawa strona równania różniczkowego postaci dy/dx = f(x, y)
  '''
  k1 = ### TWÓJ KOD TUTAJ ###
  k2 = ### TWÓJ KOD TUTAJ ###
  k3 = ### TWÓJ KOD TUTAJ ###
  k4 = ### TWÓJ KOD TUTAJ ###

  y_next = ### TWÓJ KOD TUTAJ ###
  return y_next

# %% [markdown]
# **Zad. 3** Sprawdź działanie obu metod rozwiązując równanie
#
# $\frac{dy}{dx} = -2y + 4x$
#
# w punkcie początkowym $x_0 = 0, y_0 = 1$. Zbadaj, jak zachowują się rozwiązania dla różnych wartości parametru $h$ oraz dla różnych wartości przedziału czasowego.

# %%
# Funkcja reprezentująca równanie różniczkowe
def equation(x, y):
  return ### TWÓJ KOD TUTAJ ###

# Parametry symulacji
x0 = 0  # Początkowy x
y0 = 1  # Początkowa wartość funkcji
x = ### TWÓJ KOD TUTAJ ###   # Koniec czasu
h = ### TWÓJ KOD TUTAJ ### # Delta x

# Inicjalizacja list do przechowywania wyników
iksy = np.arange(x0, x + h, h)
euler_results = []
runge_kutta_results = []

# Pętla symulacyjna
y_euler = y0
y_runge_kutta = y0
for ik in iksy:
  # Dodanie obliczonych wartości y do odpowiednich list
  euler_results.append(y_euler)
  runge_kutta_results.append(y_runge_kutta)
  # Obliczenie następnych punktów
  y_euler = ### TWÓJ KOD TUTAJ ###
  y_runge_kutta = ### TWÓJ KOD TUTAJ ###

# Wykres wyników
plt.plot(iksy, euler_results, label='Metoda Eulera')
plt.plot(iksy, runge_kutta_results, label='Metoda Runge-Kutty')
plt.xlabel('x')
plt.ylabel('Wartość funkcji')
plt.legend()
plt.show()
